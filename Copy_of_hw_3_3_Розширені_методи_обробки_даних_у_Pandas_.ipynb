# %% [markdown]
# # Домашнє завдання до теми "Розширені методи обробки даних у Pandas"

# %% [markdown]
# В цьому домашньому завданні продовжуємо працювати з набором даних `supermarket_sales.csv`.

# %% [markdown]
# 0. Імпортуйте бібліотеку pandas та зчитайте дані у змінну `df` типу `pandas.DataFrame`.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
data_path = 'drive/MyDrive/Python for Data Analysis by Hanna Pylieva/Data/supermarket_sales.csv'
df = pd.read_csv(data_path)

# %% [markdown]
# 1. Відсортуйте дані за спаданням ціни товара ('Unit price') і виведіть 5 перших рядочків на екран.

# %%
df.sort_values(by="Unit price", ascending=False).head()
#df.info()
# Out:
#       Invoice ID Branch       City Customer type Gender         Product line  \
# 983  148-41-7930      C  Naypyitaw        Normal   Male    Health and beauty
# 122  219-22-9386      B   Mandalay        Member   Male    Sports and travel
# 930  641-62-7288      B   Mandalay        Normal   Male   Home and lifestyle
# 494  437-53-3084      B   Mandalay        Normal   Male  Fashion accessories
# 283  667-92-0055      A     Yangon        Member   Male    Health and beauty
#
#      Unit price  Quantity  Tax 5%    Total       Date   Time      Payment  \
# 983       99.96         7  34.986  734.706  1/23/2019  10:33         Cash
# 122       99.96         9  44.982  944.622   3/9/2019  17:26  Credit card
# 930       99.92         6  29.976  629.496  3/24/2019  13:33      Ewallet
# 494       99.89         2   9.989  209.769  2/26/2019  11:48      Ewallet
# 283       99.83         6  29.949  628.929   3/4/2019  15:02      Ewallet
#
#        cogs  gross margin percentage  gross income  Rating
# 983  699.72                 4.761905        34.986     6.1
# 122  899.64                 4.761905        44.982     4.2
# 930  599.52                 4.761905        29.976     7.1
# 494  199.78                 4.761905         9.989     7.1
# 283  598.98                 4.761905        29.949     8.5

# %% [markdown]
# 2. Знайдіть інвойс (рядок в даних) в категорії товарів Electronic accessories, в якому був куплений товар з найбільшою кількістю і найбільшою ціною. Виведіть цей рядок даних на екран.

# %%
#df.info()
invoices = df[df['Product line'] == 'Electronic accessories']
max_quantity_price = invoices.sort_values(by=["Quantity", "Total"], ascending=[True,False]).head(1)

print(max_quantity_price)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 656  250-81-7186      C  Naypyitaw        Normal  Female
#
#                Product line  Unit price  Quantity  Tax 5%     Total  \
# 656  Electronic accessories       99.69         1  4.9845  104.6745
#
#           Date   Time      Payment   cogs  gross margin percentage  \
# 656  2/27/2019  10:23  Credit card  99.69                 4.761905
#
#      gross income  Rating
# 656        4.9845     8.0

# %% [markdown]
# 3.1. Створіть нову колонку в даних `Rating Category`, яка визначає категорію рейтингу: високий, середній чи низький за наступним правилом:
# - якщо рейтинг вищий або рівний 8 - то він високий (`High`)
# - якщо рейтинг від 6 до 8 не включаючи - то він середній (`Medium`)
# - інакше - низький (`Low`).

# %%
df['Rating category'] = df['Rating'].apply(lambda i: 'High' if i >= 8 else ('Medium' if 6 < i < 8 else 'Low'))

# %% [markdown]
# 3.2. Виведіть, який відсоток даних становить кожне зі значень категорій рейтингу.

# %%
(df['Rating category'].value_counts())/len(df)
# Out:
# Rating category
# Low       0.341
# Medium    0.330
# High      0.329
# Name: count, dtype: float64

# %% [markdown]
# 4.1. Запустіть код нижче аби створити змінну `time`. Ця змінна містить час в форматі "година:хвилина". Напишіть функцію `get_hour`, яка буде зі змінної формату як `time` дістати лише години і конвертувати їх у тип `int`.
#
# Запустіть написану функцію на змінній `time` та перевірте правильність роботи функції.

# %%
time = '11:28'

# %%
def get_hour(time):
  return int(time.split(':')[0])

get_hour(time)
# Out:
# 11

# %% [markdown]
# 4.2. З допомогою функції `get_hour` і метода `DataFrame.apply()` створіть нову колонку `Hour` в нашому наборі даних, яка буде містити години здійснення покупки, обчислені на основі часу здійснення покупки `Time`.

# %%
df['Hour'] = df['Time'].apply(get_hour)
#df[45:50]
# Out:
#      Invoice ID Branch       City Customer type  Gender  \
# 45  132-32-9879      B   Mandalay        Member  Female
# 46  370-41-7321      B   Mandalay        Member    Male
# 47  727-46-3608      B   Mandalay        Member  Female
# 48  669-54-1719      B   Mandalay        Member    Male
# 49  574-22-5561      C  Naypyitaw        Member  Female
#
#               Product line  Unit price  Quantity   Tax 5%     Total  \
# 45  Electronic accessories       93.96         4  18.7920  394.6320
# 46       Health and beauty       56.69         9  25.5105  535.7205
# 47      Food and beverages       20.01         9   9.0045  189.0945
# 48  Electronic accessories       18.93         6   5.6790  119.2590
# 49     Fashion accessories       82.63        10  41.3150  867.6150
#
#          Date   Time      Payment    cogs  gross margin percentage  \
# 45   3/9/2019  18:00         Cash  375.84                 4.761905
# 46  2/27/2019  17:24  Credit card  510.21                 4.761905
# 47   2/6/2019  15:47      Ewallet  180.09                 4.761905
# 48  2/10/2019  12:45  Credit card  113.58                 4.761905
# 49  3/19/2019  17:08      Ewallet  826.30                 4.761905
#
#     gross income  Rating Rating category  Hour
# 45       18.7920     9.5            High    18
# 46       25.5105     8.4            High    17
# 47        9.0045     4.1             Low    15
# 48        5.6790     8.1            High    12
# 49       41.3150     7.9          Medium    17

# %% [markdown]
# 4.3. Виведіть кількість значень за кожною годиною покупки і дайте відповідь "О яких годинах найбільше здійснюють покупок покупці і чому на Ваш погляд саме о цих годинах? Чи це слогічно, що найбільше покупок саме в ці години?".

# %%
df['Hour'].value_counts()
# Out:
# Hour
# 19    113
# 13    103
# 15    102
# 10    101
# 18     93
# 11     90
# 12     89
# 14     83
# 16     77
# 20     75
# 17     74
# Name: count, dtype: int64

# %% [markdown]
# Години після робочого дня, обідні перерва, вихідні дні відносно більша кількість покупок є відображенням звичайних ритмів життя споживачів та їхніх можливостей для здійснення покупок.

# %% [markdown]
# 5. Виведіть середнє значення чеку (`Total`) для покупок в містах, наявних в даних, за допомогою функції `groupby`.

# %%
df.groupby('City')['Total'].mean()
# Out:
# City
# Mandalay     319.872506
# Naypyitaw    337.099715
# Yangon       312.354031
# Name: Total, dtype: float64

# %% [markdown]
# 6. Виведіть кількість покупок, середнє, мінімальне та максимальне значення для загальної суми чеку (Total) в містах, наявних в даних, за допомогою функції groupby.
# Зробіть висновки з цих показників та дайте рекомендації для мережі супермаркетів.

# %%
df.groupby('City')['Total'].agg(['count','mean','min','max']).round(3)
#df[45:50]
# Out:
#            count     mean     min      max
# City
# Mandalay     332  319.873  18.638  1022.49
# Naypyitaw    328  337.100  10.678  1042.65
# Yangon       340  312.354  12.694  1039.29

# %% [markdown]
# **Дивлячиь на отримані дані можно зробити кільки висновків:**
#
# 1.**Кількість покупок** - найбільше покупок було здійснено в місті Yangon, а найменше - в місті Mandalay. Це може бути пов'язано з різним рівнем населення в цих містах, рівнем економічного розвитку міста або з рівнем конкуренції в галузі.
# 2. **Середнє значення чеку**- середній чек в місті Mandalay найвищий, що може вказувати на те, що клієнти в цьому місті купляють більше товарів або більш дорогі товари порівняно з іншими містами.
# 3. **Мінімальне та максимальне значення чеку** - мінімальне та максимальне значення чеку також варіюються в різних містах. Це може бути пов'язано з різним рівнем покупної спроможності мешканців різних міст.
#
# **Рекомендації:**
# 1. **Провести аналіз специфіки кожного міста**. Адаптувати ассортимент товарів відпоівдно до цього.
# 2. **Вдосконалення сервісу та ассортименту**. Базуючись на проведенному аналізі можно постіфно вдосконалювати сервіс та ассоримент товарів відповідно до потреб клієнтів.
# 3. **Розвивати бізнес в містах з найвищим потенціалом розитку**. Якщо в місті з найбільшим середнім чеком найбільга кількість покупок це може бути сигналом для розширення або вдосконалення бізнесу.

# %% [markdown]
# 7. Ми внесли деякі зміни в наш набір даних, тож, давайте запишемо результат у файл. Запишіть оновлену версію даних у файл `supermarket_sales_enriched.csv`. Зверніть увагу, аби не записати нічого зайвого, наприклад, індекси рядків нам в файлі не потрібні, оскільки вони стандартні.

# %%
df.to_csv('supermarket_sales_enriched.csv', index=False)
